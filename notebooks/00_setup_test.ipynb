# %%
# Always run first - ensures correct PyTorch for Blackwell GPU
import subprocess, sys
result = subprocess.run(
    [sys.executable, "-c", "import torch; print(torch.version.cuda)"],
    capture_output=True, text=True
)
if "12.8" not in result.stdout:
    print("Installing PyTorch for Blackwell GPU...")
    subprocess.run([
        sys.executable, "-m", "pip", "install",
        "torch==2.7.0", "torchvision==0.22.0",
        "--index-url", "https://download.pytorch.org/whl/cu128",
        "--force-reinstall", "-q"
    ])
    print("Please restart runtime now")
else:
    print(f"PyTorch CUDA {result.stdout.strip()} - correct version loaded")

# %%
# ── PHASE 0 | CELL 1 ── Clone Repository
import os

# !git clone https://savita10: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@github.com/savita10/dr-dissertation.git

os.chdir('/content/dr-dissertation')
print(f"Working directory: {os.getcwd()}")
print("Clone successful")
# Out:
# Cloning into 'dr-dissertation'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 16 (delta 0), reused 16 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 4.69 KiB | 4.69 MiB/s, done.
# Working directory: /content/dr-dissertation
# Clone successful

# %%
# ── PHASE 0 | Install Remaining Requirements
# Cell 2 - pull the fix
# !git pull https://savita10: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@github.com/savita10/dr-dissertation.git

# Cell 2 - retry requirements
# !pip install -r requirements.txt -q
print("Requirements installed")
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 3 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 497 bytes | 497.00 KiB/s, done.
# From https://github.com/savita10/dr-dissertation
#  * branch            HEAD       -> FETCH_HEAD
# Updating 4b5c93a..ce205d4
# Fast-forward
#  requirements.txt | 21 +++++++++------------
#  1 file changed, 9 insertions(+), 12 deletions(-)
# Requirements installed

# %%
# Cell 3
from src.utils.colab_setup import setup_colab
paths = setup_colab()
print("Setup complete")
print("Paths:", paths)
# Out:
# Mounted at /content/drive
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition (95.0 GB)
# RAM: 176.9 GB total
# Disk (/content): 184.5 GB free / 235.7 GB total
# Setup complete
# Paths: {'drive_root': '/content/drive/MyDrive/dissertation', 'raw_data_dir': '/content/drive/MyDrive/dissertation/raw', 'preprocessed_dir': '/content/drive/MyDrive/dissertation/preprocessed', 'features_dir': '/content/drive/MyDrive/dissertation/features', 'results_dir': '/content/drive/MyDrive/dissertation/results', 'local_cache': '/content/cache', 'local_scratch': '/content/scratch'}
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:235: UserWarning:
# NVIDIA RTX PRO 6000 Blackwell Server Edition with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_70 sm_75 sm_80 sm_86 sm_90.
# ...

# %%
# Cell 2b - upgrade PyTorch for Blackwell GPU
# !pip install torch==2.7.0 torchvision==0.22.0 --index-url https://download.pytorch.org/whl/cu128 -q
print("PyTorch upgraded")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 235.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 230.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 112.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 726.9/726.9 MB 90.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.6/609.6 MB 92.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 70.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 168.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.4/260.4 MB 118.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 MB 155.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 113.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 189.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 255.5 MB/s eta 0:00:00
# ...

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"CUDA version: {torch.version.cuda}")
    x = torch.tensor([1.0]).cuda()
    print(f"Test tensor on GPU: {x} - GPU working!")
else:
    print("WARNING: GPU not available - check PyTorch install")
# Out:
# PyTorch version: 2.5.1+cu124
# CUDA available: True
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition
# CUDA version: 12.4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1151/4118115270.py in <cell line: 0>()
#       6     print(f"CUDA version: {torch.version.cuda}")
#       7     x = torch.tensor([1.0]).cuda()
# ----> 8     print(f"Test tensor on GPU: {x} - GPU working!")
#       9 else:
#      10     print("WARNING: GPU not available - check PyTorch install")
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in __format__(self, format_spec)
#    1051             return torch._VF.split(self, split_size, dim)  # type: ignore[attr-defined]
#    1052         else:
# -> 1053             return torch._VF.split_with_sizes(self, split_size, dim)
#    1054
#    1055     def unique(self, sorted=True, return_inverse=False, return_counts=False, dim=None):
# ...

# %%
import subprocess
import sys

# Force uninstall old torch first
subprocess.run([sys.executable, "-m", "pip", "uninstall", "torch", "torchvision", "-y"],
               capture_output=True)

# Install correct version for Blackwell (sm_120) architecture
subprocess.run([
    sys.executable, "-m", "pip", "install",
    "torch==2.7.0", "torchvision==0.22.0",
    "--index-url", "https://download.pytorch.org/whl/cu128",
    "--force-reinstall", "-q"
], capture_output=True)

print("Done - now restart the runtime")
# Out:
# Done - now restart the runtime

# %%
import os
# !git clone https://savita10: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@github.com/savita10/dr-dissertation.git
os.chdir('/content/dr-dissertation')
print(f"Working directory: {os.getcwd()}")
# Out:
# fatal: destination path 'dr-dissertation' already exists and is not an empty directory.
# Working directory: /content/dr-dissertation

# %%
# !pip install torch==2.7.0 torchvision==0.22.0 \
    --index-url https://download.pytorch.org/whl/cu128 \
    --force-reinstall -q
print("PyTorch installed")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 242.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 562.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 289.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 726.9/726.9 MB 79.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.6/609.6 MB 95.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 164.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 311.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.4/260.4 MB 168.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 MB 144.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 241.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 223.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 258.7 MB/s eta 0:00:00
# ...

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"CUDA version: {torch.version.cuda}")

x = torch.ones(3, 3).cuda()
y = x * 2
print(f"GPU computation result: {y[0,0].item()} (expected 2.0)")
print("GPU working correctly!")
# Out:
# PyTorch version: 2.7.0+cu128
# CUDA available: True
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition
# CUDA version: 12.8
# GPU computation result: 2.0 (expected 2.0)
# GPU working correctly!

# %%
from src.utils.colab_setup import setup_colab
paths = setup_colab()
print("Setup complete")
print("Paths:", paths)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition (95.0 GB)
# RAM: 176.9 GB total
# Disk (/content): 181.8 GB free / 235.7 GB total
# Setup complete
# Paths: {'drive_root': '/content/drive/MyDrive/dissertation', 'raw_data_dir': '/content/drive/MyDrive/dissertation/raw', 'preprocessed_dir': '/content/drive/MyDrive/dissertation/preprocessed', 'features_dir': '/content/drive/MyDrive/dissertation/features', 'results_dir': '/content/drive/MyDrive/dissertation/results', 'local_cache': '/content/cache', 'local_scratch': '/content/scratch'}
